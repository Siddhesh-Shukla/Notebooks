# %% [markdown]
# # PANDAS

# %%
import pandas as pd
Bitsians = {
    'name': ['Siddhesh', 'Shivam', 'Aasim'],
    'branch': ['CSE', 'Mech', 'ECE'],
    'email': ['sid@email.com', 'shivam@email.com', 'aasim@gmail.com']
}
df = pd.DataFrame(Bitsians)
df
# Out:
#        name branch             email
# 0  Siddhesh    CSE     sid@email.com
# 1    Shivam   Mech  shivam@email.com
# 2     Aasim    ECE   aasim@gmail.com

# %% [markdown]
# ### import pandas as pd
#
# ### df = pd.read_csv('A.csv')
# ### df = pd.read_csv('A.csv', index_col='---')
#
# ### pd.set_option('display.max_columns', 85)
# ### pd.set_option('display.max_rows', 85)
#
# ### df.columns
# ### df.shape
# ### a,b = df.shape
#
# ### df.info()
#
# ### df.head(), df.head(10)
# ### df.tail(), df.tail(10)

# %% [markdown]
# #### df[ 'name' ] >> returns series
# #### check by type(df[ 'name' ])
# #### alternate df.name
# ### df [ [ 'name' ] ]
# ### df [ [ 'name', 'branch' ] ]

# %% [markdown]
# ## df.iloc[[row_index]] // all col
# ## OR
# ## df.loc[[row_index]]
# ## >> df.iloc [ [row_index], [col_index] ]
# ### df.iloc [ [0, 1], [1, 2] ]
# ### df.iloc [ [0, 1], : ]
# ### df.iloc [ :, [1, 2] ]
# ## >> df.loc [ [row_index], [col_name] ]
# ### df.loc [ [0, 1], ['name',  'branch'] ]
# ### df.loc[ 0:2, 'Hobbyist':'Employment' ] // IMP 2 included

# %%
# Or use counter
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %% [markdown]
# # Set Column As Index
# #### inplace = True // to apply changes in df
# ### df.set_index('col_name', inplace=True)
# #### df.index
# ### df.reset_index(inplace=True)
# ### df.sort_index(inplace=True,ascending=False)
# ### df.loc['sid@email.com']   //  search using new index
# ### df.loc['sid@email.com', 'branch']
# ### df.iloc[0]   //  IMP - still works

# %% [markdown]
# # Make Filter
# ### filt = (df['branch'] == 'ECE')
#
# ### filt = (df['branch'] == 'ECE') & (df['name'] == 'Aasim')
#
# ### filt = (df['branch'] == 'ECE') | (df['branch'] == 'Mech')
# _____________________
# ### branches = ['ECE', 'Mech']
#
# ### filt = df['branch'].isin(branches)
# _____________________
# ### filt = df['email'].str.contains('@email.com', na=False)
# _____________________
# # Access Using Filter
# ### df[filt]
# ### df.loc[filt]
# ### df.loc[filt, ['name','email']]
# ### df.loc[~filt, ['email']] // neg of filter
# # Update Using Filter
# ### df.loc[filt, ['name','email']] = ['Harsh', 'harsh@email.com']

# %% [markdown]
# # Update Column

# %% [markdown]
# ### df.columns
# ### df.columns = ['username', 'branch', 'mail']
# ### df.columns = [x.upper() for x in df.columns]
# ### df.columns = df.columns.str.replace(' ','_')

# %% [markdown]
# ##  SOME COLUMNS
# ### df.rename(columns={'name':'username','email':'mail'}, inplace=True)
# ### df['email'] = df['email'].str.lower()

# %% [markdown]
# # Update  Rows

# %% [markdown]
# ## Single Row
# ## >> All col
# ### df.loc[0] = ['Harsh', 'CSE', 'harsh@email.com']
# ## >> Some col
# ### df.loc[0, ['name','email']] = ['Harsh', 'harsh@email.com']
# ### df.loc[filt, ['name','email']] = ['Harsh', 'harsh@email.com']

# %%
import pandas as pd
Bitsians = {
    'name': ['Siddhesh', 'Shivam', 'Aasim'],
    'branch': ['CSE', 'Mech', 'ECE'],
    'email': ['sid@email.com', 'shivam@email.com', 'aasim@gmail.com']
}
df = pd.DataFrame(Bitsians)
df
# Out:
#        name branch             email
# 0  Siddhesh    CSE     sid@email.com
# 1    Shivam   Mech  shivam@email.com
# 2     Aasim    ECE   aasim@gmail.com

# %%
# multiple rows
df['branch'] = df['branch'].str.lower()
df
# Out:
#        name branch             email
# 0  Siddhesh    cse     sid@email.com
# 1    Shivam   mech  shivam@email.com
# 2     Aasim    ece   aasim@gmail.com

# %%
# update multiple rows >> apply, map, applymap, replace

# %%
# apply >> for df & series

# %%
# Series
df['email'].apply(len)
# Out:
# 0    13
# 1    16
# 2    15
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

df['email'] = df['email'].apply(update_email)
df
# Out:
#        name branch             email
# 0  Siddhesh    cse     SID@EMAIL.COM
# 1    Shivam   mech  SHIVAM@EMAIL.COM
# 2     Aasim    ece   AASIM@GMAIL.COM

# %%
df['email'] = df['email'].apply(lambda x: x.upper())
df
# Out:
#        name branch             email
# 0  Siddhesh    CSE     SID@EMAIL.COM
# 1    Shivam   Mech  SHIVAM@EMAIL.COM
# 2     Aasim    ECE   AASIM@GMAIL.COM

# %%
#1 DF
df.apply(len, axis='rows') # default axis='rows'
# Out:
# name      3
# branch    3
# email     3
# dtype: int64

# %%
df.apply(len, axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
df.apply(lambda x: x.min(), axis='rows') # x -> series
# Out:
# name                Aasim
# branch                CSE
# email     AASIM@GMAIL.COM
# dtype: object

# %%
df.apply(pd.Series.min)
# Out:
# name                Aasim
# branch                CSE
# email     AASIM@GMAIL.COM
# dtype: object

# %%
# to apply fn to every element
df.applymap(len)
# Out:
#    name  branch  email
# 0     8       3     13
# 1     6       4     16
# 2     5       3     15

# %%
df.applymap(str.lower)
# Out:
#        name branch             email
# 0  siddhesh    cse     sid@email.com
# 1    shivam   mech  shivam@email.com
# 2     aasim    ece   aasim@gmail.com

# %%
# map - only in series for substitution
df['name'] = df['name'].map({'Siddhesh': 'harsh', 'Shivam':'shiv'})
df
# value not substituted converted to NaN value (Not A Number)
# to avoid NaN, use replaceN
# Out:
#     name branch             email
# 0  harsh    CSE     sid@email.com
# 1   shiv   Mech  shivam@email.com
# 2    NaN    ECE   aasim@gmail.com

# %%
df['name'] = df['name'].replace({'Siddhesh': 'harsh', 'Shivam':'shiv'})
df
# Out:
#     name branch             email
# 0  harsh    CSE     sid@email.com
# 1   shiv   Mech  shivam@email.com
# 2  Aasim    ECE   aasim@gmail.com

# %% [markdown]
# # Add / Remove Rows & Columns

# %%
import pandas as pd
Bitsians = {
    'name': ['Siddhesh', 'Shivam', 'Aasim'],
    'branch': ['CSE', 'Mech', 'ECE'],
    'email': ['sid@email.com', 'shivam@email.com', 'aasim@gmail.com']
}
df = pd.DataFrame(Bitsians)
df
# Out:
#        name branch             email
# 0  Siddhesh    CSE     sid@email.com
# 1    Shivam   Mech  shivam@email.com
# 2     Aasim    ECE   aasim@gmail.com

# %%
df['name'] = df['name'] + ' ' + df['branch']
# df['new_col'] = df['name'] + ' ' + df['branch']
df
# Out:
#            name branch             email
# 0  Siddhesh CSE    CSE     sid@email.com
# 1   Shivam Mech   Mech  shivam@email.com
# 2     Aasim ECE    ECE   aasim@gmail.com

# %%
df['new_col'] = df['name'] + ' ' + df['branch']
df
# Out:
#        name branch             email       new_col
# 0  Siddhesh    CSE     sid@email.com  Siddhesh CSE
# 1    Shivam   Mech  shivam@email.com   Shivam Mech
# 2     Aasim    ECE   aasim@gmail.com     Aasim ECE

# %%
df['new_col'].str.split(' ') # returns list
# Out:
# 0    [Siddhesh, CSE]
# 1     [Shivam, Mech]
# 2       [Aasim, ECE]
# Name: new_col, dtype: object

# %%
df['new_col'].str.split(' ', expand=True)
# Out:
#           0     1
# 0  Siddhesh   CSE
# 1    Shivam  Mech
# 2     Aasim   ECE

# %%
df[['new', 'col']] = df['new_col'].str.split(' ', expand=True)
df
# Out:
#        name branch             email       new_col       new   col
# 0  Siddhesh    CSE     sid@email.com  Siddhesh CSE  Siddhesh   CSE
# 1    Shivam   Mech  shivam@email.com   Shivam Mech    Shivam  Mech
# 2     Aasim    ECE   aasim@gmail.com     Aasim ECE     Aasim   ECE

# %%
df.drop(columns=['new_col'], inplace=True)
df
# Out:
#        name branch             email
# 0  Siddhesh    CSE     sid@email.com
# 1    Shivam   Mech  shivam@email.com
# 2     Aasim    ECE   aasim@gmail.com

# %%
# now rows

# %%
# add 1 row
df.append({'name': 'Tony'}, ignore_index=True)
# all other col NaN
# Out:
#        name branch             email
# 0  Siddhesh    CSE     sid@email.com
# 1    Shivam   Mech  shivam@email.com
# 2     Aasim    ECE   aasim@gmail.com
# 3      Tony    NaN               NaN

# %%
import pandas as pd
Avengers = {
    'name': ['Tony', 'Bruce'],
    'email': ['tony@stark.com', 'bruce@banner.com'],
    'branch': ['AI', 'AI']
}
df2 = pd.DataFrame(Avengers)
df2
# Out:
#     name             email branch
# 0   Tony    tony@stark.com     AI
# 1  Bruce  bruce@banner.com     AI

# %%
df = df.append(df2, ignore_index=True)
df
# Out:
#        name branch             email
# 0  Siddhesh    CSE     sid@email.com
# 1    Shivam   Mech  shivam@email.com
# 2     Aasim    ECE   aasim@gmail.com
# 3      Tony     AI    tony@stark.com
# 4     Bruce     AI  bruce@banner.com

# %%
df = df.drop(index=0)
# Out:
#           name branch             email
# 1  Shivam Mech   Mech  shivam@email.com
# 2    Aasim ECE    ECE   aasim@gmail.com
# 3         Tony     AI    tony@stark.com
# 4        Bruce     AI  bruce@banner.com

# %%
filt = df['branch'] == 'CSE'
df = df.drop(index=df[filt].index)
# Out:
#      name branch             email
# 1  Shivam   Mech  shivam@email.com
# 2   Aasim    ECE   aasim@gmail.com
# 3    Tony     AI    tony@stark.com
# 4   Bruce     AI  bruce@banner.com

# %% [markdown]
# # Sort data

# %%
import pandas as pd
Bitsians = {
    'name': ['Siddhesh', 'Shivam', 'Aasim'],
    'branch': ['CSE', 'Mech', 'ECE'],
    'email': ['sid@email.com', 'shivam@email.com', 'aasim@gmail.com']
}
df = pd.DataFrame(Bitsians)
df
# Out:
#        name branch             email
# 0  Siddhesh    CSE     sid@email.com
# 1    Shivam   Mech  shivam@email.com
# 2     Aasim    ECE   aasim@gmail.com

# %%
df = df.sort_values(by='name', ascending=False)
df
# Out:
#        name branch             email
# 0  Siddhesh    CSE     sid@email.com
# 1    Shivam   Mech  shivam@email.com
# 2     Aasim    ECE   aasim@gmail.com

# %%
df = df.sort_values(by=['name', 'branch'])
df
# Out:
#        name branch             email
# 2     Aasim    ECE   aasim@gmail.com
# 1    Shivam   Mech  shivam@email.com
# 0  Siddhesh    CSE     sid@email.com

# %%
df = df.sort_values(by=['name', 'branch'], ascending=[False, True])
df
# Out:
#        name branch             email
# 0  Siddhesh    CSE     sid@email.com
# 1    Shivam   Mech  shivam@email.com
# 2     Aasim    ECE   aasim@gmail.com

# %%
df.sort_values(by=['name', 'branch'], ascending=[True, True], inplace=True)
df
# Out:
#        name branch             email
# 2     Aasim    ECE   aasim@gmail.com
# 1    Shivam   Mech  shivam@email.com
# 0  Siddhesh    CSE     sid@email.com

# %%
# to reset
# df = df.sort_index()
df.sort_index(inplace=True)
df
# Out:
#        name branch             email
# 0  Siddhesh    CSE     sid@email.com
# 1    Shivam   Mech  shivam@email.com
# 2     Aasim    ECE   aasim@gmail.com

# %%
# sort single col
df['name'].sort_values()
# Out:
# 2       Aasim
# 1      Shivam
# 0    Siddhesh
# Name: name, dtype: object

# %%
# to see top 10 salaries without sorting
df['salary'].nlargest(10) >> returns only salary col
df['salary'].nsmallest(10)

# %%
df.nlargest(10, 'salary') >> all other col as well
df.nsmallest(10, 'salary')

# %% [markdown]
# # Grouping and Aggregating data

# %%
import pandas as pd
df = pd.read_csv('Pandas Dataset/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('Pandas Dataset/survey_results_schema.csv', index_col='Column')
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
# median salary
# df['ConvertedComp'].head(15)
df['ConvertedComp'].median()
# Out:
# 54049.0

# %%
df.median()
# Out:
# Age                 29.0
# CompTotal        63000.0
# ConvertedComp    54049.0
# WorkWeekHrs         40.0
# dtype: float64

# %%
df.describe()
# df['ConvertedComp'].describe()
# count - no of NAN rows
# Out:
#                 Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242   1.037561e+05     40.782174
# std        9.585392            inf   2.268853e+05     17.816383
# min        1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05   9.500000e+04     44.000000
# max      279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
df['ConvertedComp'].count() # returns no of non-NAN rows
# Out:
# 34756

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
schema_df.loc['Ethnicity']
# Out:
# QuestionText    Which of the following describe you, if any? P...
# Name: Ethnicity, dtype: object

# %%
df['Ethnicity'].value_counts()
# Out:
# White or of European descent                                                                                                                                                                              29318
# South Asian                                                                                                                                                                                                4467
# Hispanic or Latino/a/x                                                                                                                                                                                     2256
# Black or of African descent                                                                                                                                                                                1690
# ...

# %%
df['Ethnicity'].value_counts(normalize=True)
# Out:
# White or of European descent                                                                                                                                                                              0.638069
# South Asian                                                                                                                                                                                               0.097219
# Hispanic or Latino/a/x                                                                                                                                                                                    0.049099
# Black or of African descent                                                                                                                                                                               0.036781
# ...

# %%
# Split -> apply -> combine
country_grp = df.groupby(['Country'])
country_grp

# %%
country_grp.get_group('United States')
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 8                              I am a developer by profession      Yes  36.0
# 14                             I am a developer by profession      Yes  27.0
# 17                             I am a developer by profession      Yes  25.0
# 18                             I am a developer by profession      Yes  32.0
# ...                                                       ...      ...   ...
# 58498                                                     NaN      Yes  32.0
# 58896                                                     NaN      Yes  29.0
# 60931                                                     NaN      Yes   NaN
# 63077                                                     NaN      Yes   NaN
# 64858                                                     NaN      Yes   NaN
#
# ...

# %%
filt = df['Country'] == 'United States'
df.loc[filt]['Ethnicity'].value_counts()
# Out:
# White or of European descent                                                                                                                                7737
# South Asian                                                                                                                                                  374
# Hispanic or Latino/a/x                                                                                                                                       338
# East Asian                                                                                                                                                   312
# Hispanic or Latino/a/x;White or of European descent                                                                                                          199
#                                                                                                                                                             ...
# ...

# %%
 country_grp['Ethnicity'].value_counts().head(50)
# Out:
# Country      Ethnicity
# Afghanistan  Middle Eastern                                                                                                                                                                                                                                   7
#              East Asian                                                                                                                                                                                                                                       6
#              South Asian                                                                                                                                                                                                                                      4
# ...

# %%
 country_grp['Ethnicity'].value_counts().loc['India']
# Out:
# Ethnicity
# South Asian                                                                                                                                                                                                                                    2661
# Southeast Asian                                                                                                                                                                                                                                 417
# East Asian                                                                                                                                                                                                                                      257
# South Asian;Southeast Asian                                                                                                                                                                                                                      54
# ...

# %%
country_grp['Ethnicity'].value_counts(normalize=True).loc['India']
# Out:
# Ethnicity
# South Asian                                                                                                                                                                                                                                    0.751907
# Southeast Asian                                                                                                                                                                                                                                0.117830
# East Asian                                                                                                                                                                                                                                     0.072619
# ...

# %%
country_grp['ConvertedComp'].median()
# Out:
# Country
# Afghanistan                             15163.5
# Albania                                 15900.0
# Algeria                                  9432.0
# Andorra                                 88640.0
# Angola                                   5292.0
#                                          ...
# Venezuela, Bolivarian Republic of...     3600.0
# Viet Nam                                10344.0
# Yemen                                   36000.0
# Zambia                                   5452.0
# Zimbabwe                                 7200.0
# Name: ConvertedComp, Length: 183, dtype: float64

# %%
# country_grp['ConvertedComp'].median()['India']
country_grp['ConvertedComp'].median().loc['India']
# Out:
# 10056.0

# %%
country_grp['ConvertedComp'].agg(['median', 'mean'])
# Out:
#                                        median           mean
# Country
# Afghanistan                           15163.5  148290.125000
# Albania                               15900.0   25611.000000
# Algeria                                9432.0   10362.812500
# Andorra                               88640.0   88640.000000
# Angola                                 5292.0    5292.000000
# ...                                       ...            ...
# Venezuela, Bolivarian Republic of...   3600.0    6280.611111
# Viet Nam                              10344.0   28342.605769
# Yemen                                 36000.0   36000.000000
# Zambia                                 5452.0   17506.400000
# Zimbabwe                               7200.0   26338.181818
#
# [183 rows x 2 columns]

# %%
country_grp['ConvertedComp'].agg(['median', 'mean']).loc['India']
# Out:
# median    10056.000000
# mean      28751.271364
# Name: India, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python')
# Out:
# Respondent
# 7        False
# 22        True
# 58       False
# 63        True
# 149      False
#          ...
# 54757     True
# 55407      NaN
# 62464      NaN
# 62954    False
# 64236      NaN
# Name: LanguageWorkedWith, Length: 8403, dtype: object

# %%
# how many know python
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 2670

# %%
country_grp['LanguageWorkedWith'].str.contains('Python')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-114-f83195f57315> in <module>
# ----> 1 country_grp['LanguageWorkedWith'].str.contains('Python')
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     578             return self[attr]
#     579
# --> 580         raise AttributeError(
#     581             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     582         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States       12469
# India                8403
# United Kingdom       3896
# Germany              3890
# Canada               2191
#                     ...
# Saint Lucia             1
# Liechtenstein           1
# Lesotho                 1
# Nauru                   1
# Marshall Islands        1
# Name: Country, Length: 183, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
# combining series
python_df = pd.concat([country_respondents, country_uses_python], axis=1, sort=False)
# or axis='columns'
python_df
# Out:
#                   Country  LanguageWorkedWith
# United States       12469                5964
# India                8403                2670
# United Kingdom       3896                1621
# Germany              3890                1712
# Canada               2191                1011
# ...                   ...                 ...
# Saint Lucia             1                   1
# Liechtenstein           1                   0
# Lesotho                 1                   0
# Nauru                   1                   0
# Marshall Islands        1                   0
#
# [183 rows x 2 columns]

# %%
# rename columns
python_df.rename(columns={'Country': 'NoOfRespondents', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace=True)
python_df
# Out:
#                   NoOfRespondents  NumKnowsPython
# United States               12469            5964
# India                        8403            2670
# United Kingdom               3896            1621
# Germany                      3890            1712
# Canada                       2191            1011
# ...                           ...             ...
# Saint Lucia                     1               1
# Liechtenstein                   1               0
# Lesotho                         1               0
# Nauru                           1               0
# Marshall Islands                1               0
#
# [183 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NoOfRespondents'])*100
python_df
# Out:
#                   NoOfRespondents  NumKnowsPython  PctKnowsPython
# United States               12469            5964       47.830620
# India                        8403            2670       31.774366
# United Kingdom               3896            1621       41.606776
# Germany                      3890            1712       44.010283
# Canada                       2191            1011       46.143314
# ...                           ...             ...             ...
# Saint Lucia                     1               1      100.000000
# Liechtenstein                   1               0        0.000000
# Lesotho                         1               0        0.000000
# Nauru                           1               0        0.000000
# Marshall Islands                1               0        0.000000
#
# [183 rows x 3 columns]

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)
python_df
# Out:
#                                     NoOfRespondents  NumKnowsPython  \
# Gabon                                             1               1
# Micronesia, Federated States of...                1               1
# Saint Lucia                                       1               1
# Montenegro                                       13               9
# Brunei Darussalam                                 3               2
# ...                                             ...             ...
# Lesotho                                           1               0
# Nauru                                             1               0
# Gambia                                            4               0
# Cape Verde                                        2               0
# Marshall Islands                                  1               0
#
#                                     PctKnowsPython
# Gabon                                   100.000000
# ...

# %%
python_df.loc['Japan']
# Out:
# NoOfRespondents    297.000000
# NumKnowsPython     132.000000
# PctKnowsPython      44.444444
# Name: Japan, dtype: float64

# %% [markdown]
# # Cleaning Data, Handling Missing Values

# %%
import numpy as np
import pandas as pd
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}
df = pd.DataFrame(people)
df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
# remove with missing values
df.dropna() 
# df.dropna(axis='index', how='any')
# axis = 'index' / 'columns'
# how = 'any' / 'all'
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
# drop user if email absent
df.dropna(axis='index', how='any', subset=['email'])
# df.dropna(axis='index', how='any', subset=['email', 'first'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %% [markdown]
# ## handle custom missing values

# %%
# M1 replace with NaN

df = pd.DataFrame(people)
df.replace('NA', np.nan, inplace=True)
df.replace('Missing', np.nan, inplace=True)
df
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6  False  False  False  False

# %%
df.fillna(-1) # inplace to save
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                       -1       36
# 4     -1       -1                       -1       -1
# 5     -1       -1      Anonymous@email.com       -1
# 6     NA  Missing                       NA  Missing

# %%
df.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
type(np.nan)
# Out:
# float

# %%
# df['age'] = df['age'].astype(int)  only works if no missing values
df = pd.DataFrame(people)
df.replace('NA', np.nan, inplace=True)
df.replace('Missing', np.nan, inplace=True)
df['age'] = df['age'].astype(float)
print(df['age'].mean())
df
# Out:
# 46.75
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33.0
# 1   Jane      Doe        JaneDoe@email.com  55.0
# 2   John      Doe        JohnDoe@email.com  63.0
# 3  Chris  Schafer                     None  36.0
# 4    NaN      NaN                      NaN   NaN
# 5   None      NaN      Anonymous@email.com   NaN
# 6    NaN      NaN                      NaN   NaN

# %%
df['age'].dtype
# Out:
# dtype('float64')

# %%
# handling custom no n csv

na_vals = ['NA', 'Missing']
df = pd.read_csv('Pandas Dataset/survey_results_public.csv', index_col='Respondent', na_values=na_vals)
schema_df = pd.read_csv('Pandas Dataset/survey_results_schema.csv', index_col='Column')
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df['YearsCode'].head(10)
# Out:
# Respondent
# 1     36
# 2      7
# 3      4
# 4      7
# 5     15
# 6      6
# 7      6
# 8     17
# 9      6
# 10     8
# Name: YearsCode, dtype: object

# %%
# df['YearsCode'].mean()
# doesn't work

# df['YearsCode'] = df['YearsCode'].astype(float)
# df['YearsCode'].mean()
# could not convert string to float: 'Less than 1 year'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-78f153a51b1f> in <module>
#       2 # doesn't work
#       3
# ----> 4 df['YearsCode'] = df['YearsCode'].astype(float)
#       5 df['YearsCode'].mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
# ...

# %%
df['YearsCode'].value_counts()
# Out:
# 10                    4510
# 5                     4249
# 6                     3834
# 7                     3477
# 8                     3407
# 4                     3254
# 3                     2951
# 15                    2586
# 20                    2562
# 12                    2453
# 9                     2344
# 2                     1916
# 11                    1691
# 14                    1479
# 13                    1468
# 25                    1338
# 16                    1203
# 30                    1114
# 18                    1089
# 17                    1057
# 1                      902
# 22                     792
# Less than 1 year       757
# 19                     657
# 35                     599
# 23                     572
# 21                     550
# 40                     535
# 24                     449
# 26                     378
# 27                     335
# 28                     314
# 32                     309
# 38                     289
# ...

# %%
df['YearsCode'].unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 'Less than 1 year', '3', '13',
#        '25', '16', '43', '11', '38', '33', nan, '24', '21', '12', '40',
#        '27', '50', '46', '14', '18', '28', '32', '44', '26', '42', '31',
#        '34', '29', '1', '39', '41', '45', 'More than 50 years', '47',
#        '49', '48'], dtype=object)

# %%
# 'Less than 1 year'
# 'More than 50 years'

df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
df['YearsCode'].replace('More than 50 years', 51, inplace=True)

df['YearsCode'] = df['YearsCode'].astype(float)
df['YearsCode'].mean()
# Out:
# 12.709052770265584

# %%
df['YearsCode'].median()
# Out:
# 10.0
